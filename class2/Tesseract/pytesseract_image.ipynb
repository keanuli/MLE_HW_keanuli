# %%
from PIL import Image       #pip install Pillow
import pytesseract          #pip install pytesseract

# Load an image using Pillow (PIL)
image = Image.open('IB_learner_profile.png')

# Perform OCR on the image
text = pytesseract.image_to_string(image)

print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 import pytesseract          #pip install pytesseract
#       4 # Load an image using Pillow (PIL)
# ----> 5 image = Image.open('learner-profile-en.png')
#       7 # Perform OCR on the image
#       8 text = pytesseract.image_to_string(image)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'learner-profile-en.png'
